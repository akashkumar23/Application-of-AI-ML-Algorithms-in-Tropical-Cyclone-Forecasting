# %% [markdown]
# <a href="https://colab.research.google.com/github/akashkumar23/Application-of-AI-ML-Algorithms-in-Tropical-Cyclone-Forecasting/blob/main/Time_series_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import folium
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
data = pd.read_csv("/content/drive/MyDrive/sem9/sem9/typhoon_data.csv", index_col=0)

info = pd.read_csv("/content/drive/MyDrive/sem9/sem9/typhoon_info.csv", index_col=0)
# Out:
# Mounted at /content/drive

# %%
vc = data["International number ID"].value_counts()
print(vc)
print(np.mean(vc))
# Out:
# International number ID
# 1705    111
# 116      99
# 1106     97
# 1109     94
# 14       93
#        ...
# 210       5
# 5620      3
# 1314      3
# 7013      3
# 6112      2
# Name: count, Length: 1881, dtype: int64
# 36.482721956406166

# %%
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1881 entries, 0 to 1880
# Data columns (total 6 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   International number ID                                                          1881 non-null   int64
#  1   Tropical cyclone number ID                                                       800 non-null    float64
#  2   Flag of the last data line                                                       1881 non-null   object
#  3   Difference between the time of the last data and the time of the final analysis  1881 non-null   int64
#  4   Name                                                                             1881 non-null   object
#  5   Latest Revision                                                                  1881 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 102.9+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68624 entries, 0 to 68623
# Data columns (total 17 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   International number ID                                   68624 non-null  int64
#  1   year                                                      68624 non-null  int64
#  2   month                                                     68624 non-null  int64
#  3   day                                                       68624 non-null  int64
#  4   hour                                                      68624 non-null  int64
#  5   grade                                                     68624 non-null  object
#  6   Latitude of the center                                    68624 non-null  int64
#  7   Longitude of the center                                   68624 non-null  int64
#  8   Central pressure                                          68624 non-null  int64
#  9   Maximum sustained wind speed                              43356 non-null  float64
#  10  Direction of the longest radius of 50kt winds or greater  27208 non-null  object
#  11  The longeast radius of 50kt winds or greater              27208 non-null  float64
#  12  The shortest radius of 50kt winds or greater              27208 non-null  float64
#  13  Direction of the longest radius of 30kt winds or greater  27208 non-null  object
#  14  The longeast radius of 30kt winds or greater              27208 non-null  float64
#  15  The shortest radius of 30kt winds or greater              27208 non-null  float64
#  16  Indicator of landfall or passage                          68624 non-null  object
# dtypes: float64(5), int64(8), object(4)
# memory usage: 9.4+ MB

# %%
data[data["Maximum sustained wind speed"].isna()]
# Out:
#        International number ID  year  month  day  hour  \
# 0                         5101  1951      2   19     6
# 1                         5101  1951      2   19    12
# 2                         5101  1951      2   19    18
# 3                         5101  1951      2   20     0
# 4                         5101  1951      2   20     6
# ...                        ...   ...    ...  ...   ...
# 25263                     7625  1976     12    9    18
# 25264                     7625  1976     12   10     0
# 25265                     7625  1976     12   10     6
# 25266                     7625  1976     12   10    12
# 25267                     7625  1976     12   10    18
#
#                                             grade  Latitude of the center  \
# 0                             Tropical Depression                     200
# 1                             Tropical Depression                     200
# 2                             Tropical Depression                     230
# 3      Tropical Cyclone of TS intensity or higher                     250
# 4      Tropical Cyclone of TS intensity or higher                     276
# ...                                           ...                     ...
# 25263  Tropical Cyclone of TS intensity or higher                     196
# 25264  Tropical Cyclone of TS intensity or higher                     197
# 25265  Tropical Cyclone of TS intensity or higher                     198
# 25266                         Tropical Depression                     199
# 25267                         Tropical Depression                     200
#
#        Longitude of the center  Central pressure  \
# 0                         1385              1010
# 1                         1385              1010
# 2                         1421              1000
# 3                         1460               994
# 4                         1506               994
# ...                        ...               ...
# 25263                     1367               998
# 25264                     1380               998
# 25265                     1390               998
# 25266                     1400              1004
# 25267                     1410              1008
#
#        Maximum sustained wind speed  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 25263                           NaN
# 25264                           NaN
# 25265                           NaN
# 25266                           NaN
# 25267                           NaN
#
#       Direction of the longest radius of 50kt winds or greater  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25263                                                NaN
# 25264                                                NaN
# 25265                                                NaN
# 25266                                                NaN
# 25267                                                NaN
#
#        The longeast radius of 50kt winds or greater  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 25263                                           NaN
# 25264                                           NaN
# 25265                                           NaN
# 25266                                           NaN
# 25267                                           NaN
#
#        The shortest radius of 50kt winds or greater  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 25263                                           NaN
# 25264                                           NaN
# 25265                                           NaN
# 25266                                           NaN
# 25267                                           NaN
#
#       Direction of the longest radius of 30kt winds or greater  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25263                                                NaN
# 25264                                                NaN
# 25265                                                NaN
# 25266                                                NaN
# 25267                                                NaN
#
#        The longeast radius of 30kt winds or greater  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 25263                                           NaN
# 25264                                           NaN
# 25265                                           NaN
# 25266                                           NaN
# 25267                                           NaN
#
#        The shortest radius of 30kt winds or greater  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 25263                                           NaN
# 25264                                           NaN
# 25265                                           NaN
# 25266                                           NaN
# 25267                                           NaN
#
#       Indicator of landfall or passage
# 0
# 1
# 2
# 3
# 4
# ...                                ...
# 25263
# 25264
# 25265
# 25266
# 25267
#
# [25268 rows x 17 columns]

# %%
data[25268:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43356 entries, 25268 to 68623
# Data columns (total 17 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   International number ID                                   43356 non-null  int64
#  1   year                                                      43356 non-null  int64
#  2   month                                                     43356 non-null  int64
#  3   day                                                       43356 non-null  int64
#  4   hour                                                      43356 non-null  int64
#  5   grade                                                     43356 non-null  object
#  6   Latitude of the center                                    43356 non-null  int64
#  7   Longitude of the center                                   43356 non-null  int64
#  8   Central pressure                                          43356 non-null  int64
#  9   Maximum sustained wind speed                              43356 non-null  float64
#  10  Direction of the longest radius of 50kt winds or greater  27208 non-null  object
#  11  The longeast radius of 50kt winds or greater              27208 non-null  float64
#  12  The shortest radius of 50kt winds or greater              27208 non-null  float64
#  13  Direction of the longest radius of 30kt winds or greater  27208 non-null  object
#  14  The longeast radius of 30kt winds or greater              27208 non-null  float64
#  15  The shortest radius of 30kt winds or greater              27208 non-null  float64
#  16  Indicator of landfall or passage                          43356 non-null  object
# dtypes: float64(5), int64(8), object(4)
# memory usage: 6.0+ MB

# %%
data[25277:25281]
# Out:
#        International number ID  year  month  day  hour                grade  \
# 25277                     7701  1977      3   29     6       Tropical Storm
# 25278                     7701  1977      3   29    12       Tropical Storm
# 25279                     7701  1977      3   29    18       Tropical Storm
# 25280                     7701  1977      3   30     0  Tropical Depression
# 25281                     7701  1977      3   30     6  Tropical Depression
# 25282                     7701  1977      3   30    12  Tropical Depression
# 25283                     7701  1977      3   30    18  Tropical Depression
# 25284                     7701  1977      3   31     0  Tropical Depression
# 25285                     7702  1977      6   13     0  Tropical Depression
# 25286                     7702  1977      6   13     6  Tropical Depression
# 25287                     7702  1977      6   13    12  Tropical Depression
# 25288                     7702  1977      6   13    18  Tropical Depression
# 25289                     7702  1977      6   14     0       Tropical Storm
#
#        Latitude of the center  Longitude of the center  Central pressure  \
# 25277                      78                     1553              1002
# 25278                      84                     1539              1002
# 25279                      90                     1529              1004
# 25280                      95                     1516              1006
# 25281                      97                     1510              1006
# 25282                      98                     1506              1008
# 25283                      99                     1502              1008
# 25284                     100                     1496              1008
# 25285                     130                     1180              1008
# 25286                     135                     1176              1004
# 25287                     142                     1173              1004
# 25288                     149                     1171              1000
# 25289                     156                     1171               992
#
#        Maximum sustained wind speed  \
# 25277                          45.0
# 25278                          40.0
# 25279                          40.0
# 25280                           0.0
# 25281                           0.0
# 25282                           0.0
# 25283                           0.0
# 25284                           0.0
# 25285                           0.0
# 25286                           0.0
# 25287                           0.0
# 25288                           0.0
# 25289                          40.0
#
#       Direction of the longest radius of 50kt winds or greater  \
# 25277                                       No direction
# 25278                                       No direction
# 25279                                       No direction
# 25280                                                NaN
# 25281                                                NaN
# 25282                                                NaN
# 25283                                                NaN
# 25284                                                NaN
# 25285                                                NaN
# 25286                                                NaN
# 25287                                                NaN
# 25288                                                NaN
# 25289                                       No direction
#
#        The longeast radius of 50kt winds or greater  \
# 25277                                           0.0
# 25278                                           0.0
# 25279                                           0.0
# 25280                                           NaN
# 25281                                           NaN
# 25282                                           NaN
# 25283                                           NaN
# 25284                                           NaN
# 25285                                           NaN
# 25286                                           NaN
# 25287                                           NaN
# 25288                                           NaN
# 25289                                           0.0
#
#        The shortest radius of 50kt winds or greater  \
# 25277                                           0.0
# 25278                                           0.0
# 25279                                           0.0
# 25280                                           NaN
# 25281                                           NaN
# 25282                                           NaN
# 25283                                           NaN
# 25284                                           NaN
# 25285                                           NaN
# 25286                                           NaN
# 25287                                           NaN
# 25288                                           NaN
# 25289                                           0.0
#
#       Direction of the longest radius of 30kt winds or greater  \
# 25277                                 (symmetric circle)
# 25278                                 (symmetric circle)
# 25279                                 (symmetric circle)
# 25280                                                NaN
# 25281                                                NaN
# 25282                                                NaN
# 25283                                                NaN
# 25284                                                NaN
# 25285                                                NaN
# 25286                                                NaN
# 25287                                                NaN
# 25288                                                NaN
# 25289                                 (symmetric circle)
#
#        The longeast radius of 30kt winds or greater  \
# 25277                                         100.0
# 25278                                          50.0
# 25279                                          50.0
# 25280                                           NaN
# 25281                                           NaN
# 25282                                           NaN
# 25283                                           NaN
# 25284                                           NaN
# 25285                                           NaN
# 25286                                           NaN
# 25287                                           NaN
# 25288                                           NaN
# 25289                                          75.0
#
#        The shortest radius of 30kt winds or greater  \
# 25277                                         100.0
# 25278                                          50.0
# 25279                                          50.0
# 25280                                           NaN
# 25281                                           NaN
# 25282                                           NaN
# 25283                                           NaN
# 25284                                           NaN
# 25285                                           NaN
# 25286                                           NaN
# 25287                                           NaN
# 25288                                           NaN
# 25289                                          75.0
#
#       Indicator of landfall or passage
# 25277
# 25278
# 25279
# 25280
# 25281
# 25282
# 25283
# 25284
# 25285
# 25286
# 25287
# 25288
# 25289

# %%
data[data["Direction of the longest radius of 50kt winds or greater"].isna()]["grade"].unique()
# Out:
# array(['Tropical Depression',
#        'Tropical Cyclone of TS intensity or higher',
#        'Extra-tropical Cyclone',
#        'Just entering into the responsible area of RSMC Tokyo-Typhoon Center'],
#       dtype=object)

# %%
data[data["Direction of the longest radius of 50kt winds or greater"].notna()]["grade"].unique()
# Out:
# array(['Severe Tropical Storm', 'Tropical Storm', 'Typhoon',
#        'Just entering into the responsible area of RSMC Tokyo-Typhoon Center'],
#       dtype=object)

# %%
data[data["year"] < 1977]["grade"].unique()
# Out:
# array(['Tropical Depression',
#        'Tropical Cyclone of TS intensity or higher',
#        'Extra-tropical Cyclone',
#        'Just entering into the responsible area of RSMC Tokyo-Typhoon Center'],
#       dtype=object)

# %%
data[data["year"] >= 1977]["grade"].unique()
# Out:
# array(['Tropical Depression', 'Severe Tropical Storm', 'Tropical Storm',
#        'Extra-tropical Cyclone', 'Typhoon',
#        'Just entering into the responsible area of RSMC Tokyo-Typhoon Center'],
#       dtype=object)

# %%
data = data[data["year"] >= 1977]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43356 entries, 25268 to 68623
# Data columns (total 17 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   International number ID                                   43356 non-null  int64
#  1   year                                                      43356 non-null  int64
#  2   month                                                     43356 non-null  int64
#  3   day                                                       43356 non-null  int64
#  4   hour                                                      43356 non-null  int64
#  5   grade                                                     43356 non-null  object
#  6   Latitude of the center                                    43356 non-null  int64
#  7   Longitude of the center                                   43356 non-null  int64
#  8   Central pressure                                          43356 non-null  int64
#  9   Maximum sustained wind speed                              43356 non-null  float64
#  10  Direction of the longest radius of 50kt winds or greater  27208 non-null  object
#  11  The longeast radius of 50kt winds or greater              27208 non-null  float64
#  12  The shortest radius of 50kt winds or greater              27208 non-null  float64
#  13  Direction of the longest radius of 30kt winds or greater  27208 non-null  object
#  14  The longeast radius of 30kt winds or greater              27208 non-null  float64
#  15  The shortest radius of 30kt winds or greater              27208 non-null  float64
#  16  Indicator of landfall or passage                          43356 non-null  object
# dtypes: float64(5), int64(8), object(4)
# memory usage: 6.0+ MB

# %%
print(data[data["Direction of the longest radius of 50kt winds or greater"].notna()]["grade"].unique())
print(data[data["Direction of the longest radius of 50kt winds or greater"].isna()]["grade"].unique())
# Out:
# ['Severe Tropical Storm' 'Tropical Storm' 'Typhoon'
#  'Just entering into the responsible area of RSMC Tokyo-Typhoon Center']
# ['Tropical Depression' 'Extra-tropical Cyclone'
#  'Just entering into the responsible area of RSMC Tokyo-Typhoon Center']

# %%
typhoons = data["International number ID"].unique() # Unique IDs of typhoons
info[info["Name"].str.strip() == "MAEMI"]
# Out:
#       International number ID  Tropical cyclone number ID  \
# 1408                      314                        20.0
#
#      Flag of the last data line  \
# 1408                Dissipation
#
#       Difference between the time of the last data and the time of the final analysis  \
# 1408                                                  6
#
#                       Name Latest Revision
# 1408                 MAEMI      2004-02-17

# %%
maemi_data = data.copy()[data["International number ID"]==314]
maemi_data
# Out:
#        International number ID  year  month  day  hour  \
# 51288                      314  2003      9    4     0
# 51289                      314  2003      9    4     6
# 51290                      314  2003      9    4    12
# 51291                      314  2003      9    4    18
# 51292                      314  2003      9    5     0
# ...                        ...   ...    ...  ...   ...
# 51345                      314  2003      9   15     0
# 51346                      314  2003      9   15     6
# 51347                      314  2003      9   15    12
# 51348                      314  2003      9   15    18
# 51349                      314  2003      9   16     0
#
#                         grade  Latitude of the center  \
# 51288     Tropical Depression                      99
# 51289     Tropical Depression                     104
# 51290     Tropical Depression                     109
# 51291     Tropical Depression                     117
# 51292     Tropical Depression                     125
# ...                       ...                     ...
# 51345  Extra-tropical Cyclone                     488
# 51346  Extra-tropical Cyclone                     490
# 51347  Extra-tropical Cyclone                     492
# 51348  Extra-tropical Cyclone                     489
# 51349  Extra-tropical Cyclone                     489
#
#        Longitude of the center  Central pressure  \
# 51288                     1531              1008
# 51289                     1511              1006
# 51290                     1497              1006
# 51291                     1487              1004
# 51292                     1475              1004
# ...                        ...               ...
# 51345                     1506               988
# 51346                     1511               992
# 51347                     1514               996
# 51348                     1525               996
# 51349                     1534               996
#
#        Maximum sustained wind speed  \
# 51288                           0.0
# 51289                           0.0
# 51290                           0.0
# 51291                           0.0
# 51292                           0.0
# ...                             ...
# 51345                           0.0
# 51346                           0.0
# 51347                           0.0
# 51348                           0.0
# 51349                           0.0
#
#       Direction of the longest radius of 50kt winds or greater  \
# 51288                                                NaN
# 51289                                                NaN
# 51290                                                NaN
# 51291                                                NaN
# 51292                                                NaN
# ...                                                  ...
# 51345                                                NaN
# 51346                                                NaN
# 51347                                                NaN
# 51348                                                NaN
# 51349                                                NaN
#
#        The longeast radius of 50kt winds or greater  \
# 51288                                           NaN
# 51289                                           NaN
# 51290                                           NaN
# 51291                                           NaN
# 51292                                           NaN
# ...                                             ...
# 51345                                           NaN
# 51346                                           NaN
# 51347                                           NaN
# 51348                                           NaN
# 51349                                           NaN
#
#        The shortest radius of 50kt winds or greater  \
# 51288                                           NaN
# 51289                                           NaN
# 51290                                           NaN
# 51291                                           NaN
# 51292                                           NaN
# ...                                             ...
# 51345                                           NaN
# 51346                                           NaN
# 51347                                           NaN
# 51348                                           NaN
# 51349                                           NaN
#
#       Direction of the longest radius of 30kt winds or greater  \
# 51288                                                NaN
# 51289                                                NaN
# 51290                                                NaN
# 51291                                                NaN
# 51292                                                NaN
# ...                                                  ...
# 51345                                                NaN
# 51346                                                NaN
# 51347                                                NaN
# 51348                                                NaN
# 51349                                                NaN
#
#        The longeast radius of 30kt winds or greater  \
# 51288                                           NaN
# 51289                                           NaN
# 51290                                           NaN
# 51291                                           NaN
# 51292                                           NaN
# ...                                             ...
# 51345                                           NaN
# 51346                                           NaN
# 51347                                           NaN
# 51348                                           NaN
# 51349                                           NaN
#
#        The shortest radius of 30kt winds or greater  \
# 51288                                           NaN
# 51289                                           NaN
# 51290                                           NaN
# 51291                                           NaN
# 51292                                           NaN
# ...                                             ...
# 51345                                           NaN
# 51346                                           NaN
# 51347                                           NaN
# 51348                                           NaN
# 51349                                           NaN
#
#       Indicator of landfall or passage
# 51288
# 51289
# 51290
# 51291
# 51292
# ...                                ...
# 51345
# 51346
# 51347
# 51348
# 51349
#
# [62 rows x 17 columns]

# %%
maemi_data[30:35]
# Out:
#        International number ID  year  month  day  hour    grade  \
# 51318                      314  2003      9   10    18  Typhoon
# 51319                      314  2003      9   10    19  Typhoon
# 51320                      314  2003      9   10    21  Typhoon
# 51321                      314  2003      9   11     0  Typhoon
# 51322                      314  2003      9   11     3  Typhoon
#
#        Latitude of the center  Longitude of the center  Central pressure  \
# 51318                     247                     1254               910
# 51319                     248                     1254               910
# 51320                     250                     1253               910
# 51321                     252                     1251               910
# 51322                     255                     1252               920
#
#        Maximum sustained wind speed  \
# 51318                         105.0
# 51319                         105.0
# 51320                         105.0
# 51321                         105.0
# 51322                          95.0
#
#       Direction of the longest radius of 50kt winds or greater  \
# 51318                                 (symmetric circle)
# 51319                                 (symmetric circle)
# 51320                                 (symmetric circle)
# 51321                                               East
# 51322                                               East
#
#        The longeast radius of 50kt winds or greater  \
# 51318                                          80.0
# 51319                                          80.0
# 51320                                          80.0
# 51321                                          80.0
# 51322                                          70.0
#
#        The shortest radius of 50kt winds or greater  \
# 51318                                          80.0
# 51319                                          80.0
# 51320                                          80.0
# 51321                                          60.0
# 51322                                          50.0
#
#       Direction of the longest radius of 30kt winds or greater  \
# 51318                                               East
# 51319                                               East
# 51320                                               East
# 51321                                               East
# 51322                                               East
#
#        The longeast radius of 30kt winds or greater  \
# 51318                                         240.0
# 51319                                         240.0
# 51320                                         240.0
# 51321                                         250.0
# 51322                                         250.0
#
#        The shortest radius of 30kt winds or greater  \
# 51318                                         180.0
# 51319                                         200.0
# 51320                                         200.0
# 51321                                         200.0
# 51322                                         220.0
#
#       Indicator of landfall or passage
# 51318
# 51319                                #
# 51320
# 51321
# 51322

# %%
maemi_data["Elapsed Hour"] = (maemi_data["day"]-4)*24 + maemi_data["hour"]
maemi_data.head()
# Out:
#        International number ID  year  month  day  hour                grade  \
# 51288                      314  2003      9    4     0  Tropical Depression
# 51289                      314  2003      9    4     6  Tropical Depression
# 51290                      314  2003      9    4    12  Tropical Depression
# 51291                      314  2003      9    4    18  Tropical Depression
# 51292                      314  2003      9    5     0  Tropical Depression
#
#        Latitude of the center  Longitude of the center  Central pressure  \
# 51288                      99                     1531              1008
# 51289                     104                     1511              1006
# 51290                     109                     1497              1006
# 51291                     117                     1487              1004
# 51292                     125                     1475              1004
#
#        Maximum sustained wind speed  \
# 51288                           0.0
# 51289                           0.0
# 51290                           0.0
# 51291                           0.0
# 51292                           0.0
#
#       Direction of the longest radius of 50kt winds or greater  \
# 51288                                                NaN
# 51289                                                NaN
# 51290                                                NaN
# 51291                                                NaN
# 51292                                                NaN
#
#        The longeast radius of 50kt winds or greater  \
# 51288                                           NaN
# 51289                                           NaN
# 51290                                           NaN
# 51291                                           NaN
# 51292                                           NaN
#
#        The shortest radius of 50kt winds or greater  \
# 51288                                           NaN
# 51289                                           NaN
# 51290                                           NaN
# 51291                                           NaN
# 51292                                           NaN
#
#       Direction of the longest radius of 30kt winds or greater  \
# 51288                                                NaN
# 51289                                                NaN
# 51290                                                NaN
# 51291                                                NaN
# 51292                                                NaN
#
#        The longeast radius of 30kt winds or greater  \
# 51288                                           NaN
# 51289                                           NaN
# 51290                                           NaN
# 51291                                           NaN
# 51292                                           NaN
#
#        The shortest radius of 30kt winds or greater  \
# 51288                                           NaN
# 51289                                           NaN
# 51290                                           NaN
# 51291                                           NaN
# 51292                                           NaN
#
#       Indicator of landfall or passage  Elapsed Hour
# 51288                                              0
# 51289                                              6
# 51290                                             12
# 51291                                             18
# 51292                                             24

# %%
maemi_data = maemi_data.drop(["International number ID", "year", "month", "day", "hour"], axis=1)
maemi_data.head()
# Out:
#                      grade  Latitude of the center  Longitude of the center  \
# 51288  Tropical Depression                      99                     1531
# 51289  Tropical Depression                     104                     1511
# 51290  Tropical Depression                     109                     1497
# 51291  Tropical Depression                     117                     1487
# 51292  Tropical Depression                     125                     1475
#
#        Central pressure  Maximum sustained wind speed  \
# 51288              1008                           0.0
# 51289              1006                           0.0
# 51290              1006                           0.0
# 51291              1004                           0.0
# 51292              1004                           0.0
#
#       Direction of the longest radius of 50kt winds or greater  \
# 51288                                                NaN
# 51289                                                NaN
# 51290                                                NaN
# 51291                                                NaN
# 51292                                                NaN
#
#        The longeast radius of 50kt winds or greater  \
# 51288                                           NaN
# 51289                                           NaN
# 51290                                           NaN
# 51291                                           NaN
# 51292                                           NaN
#
#        The shortest radius of 50kt winds or greater  \
# 51288                                           NaN
# 51289                                           NaN
# 51290                                           NaN
# 51291                                           NaN
# 51292                                           NaN
#
#       Direction of the longest radius of 30kt winds or greater  \
# 51288                                                NaN
# 51289                                                NaN
# 51290                                                NaN
# 51291                                                NaN
# 51292                                                NaN
#
#        The longeast radius of 30kt winds or greater  \
# 51288                                           NaN
# 51289                                           NaN
# 51290                                           NaN
# 51291                                           NaN
# 51292                                           NaN
#
#        The shortest radius of 30kt winds or greater  \
# 51288                                           NaN
# 51289                                           NaN
# 51290                                           NaN
# 51291                                           NaN
# 51292                                           NaN
#
#       Indicator of landfall or passage  Elapsed Hour
# 51288                                              0
# 51289                                              6
# 51290                                             12
# 51291                                             18
# 51292                                             24

# %%
maemi_data["Longitude of the center"] /= 10
maemi_data["Latitude of the center"] /= 10

# %%
fig = plt.figure(figsize=(3,3))
plt.xlim(120, 170)
plt.ylim(5, 55)
plt.plot(maemi_data["Longitude of the center"], maemi_data["Latitude of the center"], "red")
plt.show()

# %%
scale = maemi_data["The longeast radius of 30kt winds or greater"].fillna(60)
fig = plt.figure(figsize=(5,5))
plt.xlim(120, 170)
plt.ylim(5, 55)
plt.plot(maemi_data["Longitude of the center"], maemi_data["Latitude of the center"], "black", linewidth=1)
plt.scatter(maemi_data["Longitude of the center"], maemi_data["Latitude of the center"], s=scale/3, c=maemi_data["Maximum sustained wind speed"])
plt.show()

# %%
# Color map
import matplotlib as mpl
import matplotlib.cm as cm

c = maemi_data.copy()["Maximum sustained wind speed"]
cmap = cm.jet

# %%
def rgb_to_hex(rgb):
    return '#%02x%02x%02x' % rgb
m = folium.Map(location=[38.9, 153.2], zoom_start=3, width=600, height=600)
for i in range(len(maemi_data)):
    color = cmap(c.iloc[i]/c.max())
    color = tuple([int(c*255) for c in color[:3]])
    color = rgb_to_hex(color)
    folium.Circle(location=[maemi_data.iloc[i]["Latitude of the center"], maemi_data.iloc[i]["Longitude of the center"]],
                 radius=scale.iloc[i]*1852,  #  nautical mile to meter
                 fill=True,
                 color="black",
                 fill_color=color).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bd8588a3eb2bd8f1c85754b0e13b8ad {
#                     position: relative;
#                     width: 600.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bd8588a3eb2bd8f1c85754b0e13b8ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bd8588a3eb2bd8f1c85754b0e13b8ad = L.map(
#                 &quot;map_3bd8588a3eb2bd8f1c85754b0e13b8ad&quot;,
#                 {
#                     center: [38.9, 153.2],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3801581088f7b36f4dd7bb24916f675 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c3801581088f7b36f4dd7bb24916f675.addTo(map_3bd8588a3eb2bd8f1c85754b0e13b8ad);
#
#
#             var circle_4aae4b82e940e94b83c547595d468128 = L.circle(
#                 [9.9, 153.1],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00007f&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 111120.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bd8588a3eb2bd8f1c85754b0e13b8ad);
#
#
#             var circle_318f84bc5c9d40d8d9b65bb55d446387 = L.circle(
#                 [10.4, 151.1],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00007f&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 111120.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bd8588a3eb2bd8f1c85754b0e13b8ad);
#
#
#             var circle_8238fa8cfaf6f773910088c24d4e7a39 = L.circle(
#                 [10.9, 149.7],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00007f&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 111120.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bd8588a3eb2bd8f1c85754b0e13b8ad);
#
#
#             var circle_8666c99edcf11962d8a37805b4c25a6e = L.circle(
#                 [11.7, 148.7],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00007f&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 111120.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bd8588a3eb2bd8f1c85754b0e13b8ad);
#
#
#             var circle_1878a50b382babd1bac2fb9087eee5a6 = L.circle(
#                 [12.5, 147.5],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00007f&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 111120.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bd8588a3eb2bd8f1c85754b0e13b8ad);
#
#
#             var circle_4ee0c1cbc532540fded67e360e7436ab = L.circle(
#                 [12.9, 145.8],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#00007f&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 111120.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3bd8588a3eb2bd8f1c85754b0e13b8ad);
#
#
#             var circle_2ef4fd8361050a7c0e604b0551ad182c = L.circle(
#                 [13.8, 145.1],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&q

# %%
plt.title("Typhoon's Central Pressure in hPa")
plt.plot(maemi_data["Elapsed Hour"],maemi_data["Central pressure"])
plt.xlabel("Elapsed Hour")
plt.ylabel("Central Pressure")
plt.legend()
plt.show()
# Out:
# <ipython-input-27-0f8b49d51936>:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.title("Typhoon's Wind Speed in knot(kt)")
plt.plot(maemi_data["Elapsed Hour"],maemi_data["Maximum sustained wind speed"])
plt.xlabel("Elapsed Hour")
plt.ylabel("Maximum sustained wind speed")
plt.legend()
plt.show()
# Out:
# <ipython-input-28-cee2433672f1>:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
